# %%
2 + 2
# Out:
# 4

# %% [markdown]
# Let's try something!

# %%
print ('Hello!')
print (2 + 2)
# Out:
# Hello!
# 4

# %%
2 + 5
# Out:
# 7

# %%
10 - 5
# Out:
# 5

# %%
12341754809 + 1283740192740123
# Out:
# 1283752534494932

# %%
11111 * 1111111
# Out:
# 12345554321

# %%
40 // 8
# Out:
# 5

# %%
42 // 8
# Out:
# 5

# %%
42 % 8
# Out:
# 2

# %%
42 / (4 + 2 * -2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-7ff27b1b8d2e> in <module>
# ----> 1 42 / (4 + 2 * -2)
#
# ZeroDivisionError: division by zero

# %%
239 % 10
# Out:
# 9

# %%
239 // 10
# Out:
# 23

# %%
2 ** 2
# Out:
# 4

# %%
2014 ** 14
# Out:
# 18064773765607550801425251468864907833685590016

# %%
- (42)
# Out:
# -42

# %%
+ (42)
# Out:
# 42

# %%
+-+42
# Out:
# -42

# %%
-*42
# Out:
#   File "<ipython-input-21-761874de80cf>", line 1
#     -*42
#      ^
# SyntaxError: invalid syntax

# %%
print('test')
# Out:
# test

# %%
5 // 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-23-e6530c2158eb> in <module>
# ----> 1 5 // 0
#
# ZeroDivisionError: integer division or modulo by zero

# %%
0.5
# Out:
# 0.5

# %%
0.5 + 0.3
# Out:
# 0.8

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
1 / 3
# Out:
# 0.3333333333333333

# %%
0.3 + 0.3 + 0.3
# Out:
# 0.8999999999999999

# %%
2 ** 5
# Out:
# 32

# %%
9 ** 0.5
# Out:
# 3.0

# %%
5e-1
# Out:
# 0.5

# %%
1234e-2
# Out:
# 12.34

# %%
1234e2
# Out:
# 123400.0

# %%
1.2345e3
# Out:
# 1234.5

# %%
1.2345e-3
# Out:
# 0.0012345

# %%
2014.0 ** 14
# Out:
# 1.806477376560755e+46

# %%
7 / 3
# Out:
# 2.3333333333333335

# %%
int(2.99)
# Out:
# 2

# %%
int(-1.6)
# Out:
# -1

# %%
9 ** 19 - int(float(9**19))
# Out:
# 89

# %%
a = 'string'
b = 'another string'
print(a, b)
# Out:
# string another string

# %%
print(a + b)
# Out:
# stringanother string

# %%
print(a)
"""
multipline
comment
"""
print(b)
# Out:
# string
# another string

# %%
print(a + '\n' + b) # print in two different lines
# Out:
# string
# another string

# %%
В то далёкое время, когда Паша ходил в школу, ему очень не нравилась формула Герона для вычисления площади треугольника, так как казалась слишком сложной. В один прекрасный момент Павел решил избавить всех школьников от страданий и написать и распространить по школам программу, вычисляющую площадь треугольника по трём сторонам.

Одна проблема: так как эта формула не нравилась Павлу, он её не запомнил. Помогите ему завершить доброе дело и напишите программу, вычисляющую площадь треугольника по переданным длинам трёх его сторон по формуле Герона:

S=\sqrt{p(p−a)(p−b)(p−c)}
S= 
p(p−a)(p−b)(p−c)
​	
 
где p=\dfrac{a+b+c}2p= 
2
a+b+c
​	
  – полупериметр треугольника. На вход программе подаются целые числа, выводом программы должно являться вещественное число, соответствующее площади треугольника.

# %%
a = int(input())
b = int(input())
c = int(input())

p = (a + b + c)/2
s = (p*(p - a)*(p-b)*(p-c)) ** 0.5
print(s)
# Out:
# 3
# 4
# 5
# 6.0

# %%
x = int(input())

if x > -15 and x <=12:
    print("True")
elif x > 14 and x < 17:
    print("True")
elif x >= 19:
    print("True")
else:
    print("False")
# Out:
# -20
# False

# %%
a = float(input())
b = float(input())
d = input()

if d == "+":
    print(a + b)
elif d == "-":
    print(a - b)
elif d == "/":
    if b == 0:
        print("Деление на 0!")
    else:
        print(a / b)
elif d == "*":
    print(a * b)
elif d == "mod":
    if b == 0:
        print("Деление на 0!")
    else:
        print(a % b)
elif d == "pow":
    print(a ** b)
elif d == "div":
    if b == 0:
        print("Деление на 0!")
    else:
        print(a // b)
else:
    pass
# Out:
# 5
# 0
# /
# Деление на 0!

# %%
def triangle():
    a = int(input())
    b = int(input())
    c = int(input())
    p = (a + b + c)/2
    s = (p*(p - a)*(p-b)*(p-c)) ** 0.5
    print(s)

def square():
    a = int(input())
    b = int(input())
    print(a * b)
    
def cirle():
    r = int(input())
    print(3.14 * (r ** 2))

    
type = input()

if type == 'треугольник':
    triangle()
elif type == 'прямоугольник':
    square()
elif type == 'круг':
    cirle()
else:
    print('Error 404')
# Out:
# круг
# 5
# 78.5

# %%
a, b, c = int(input()), int(input()), int(input())
ai, bi, ci = 0, 0, 0
# Find max value
if a >= b and a >= c:
    ai = 1
    print(a)
elif b >= a and b >= c:
    bi = 1
    print(b)
elif c >= a and c >= b:
    ci = 1
    print(c)
else:
    pass

# Find min value
if a <= b and a <= c:
    ai = 1
    print(a)
elif b <= a and b <= c:
    bi = 1
    print(b)
elif c <= a and c <= b:
    ci = 1
    print(c)
else:
    pass

# Find other value
if ai == 1 and bi == 1:
    print(c)
elif bi == 1 and ci == 1:
    print(a)
elif ci == 1 and ai == 1:
    print(b)
elif a == b == c:
    print(a)
else:
    pass
# Out:
# 123
# 456
# 79
# 456
# 79
# 123

# %%
x = int(input())

if x >= 11 and x <= 19:
    print(x, "программистов")
elif x % 100 >= 11 and x % 100 <= 14:
    print(x, "программистов")
elif x % 10 == 1:
    print(x, "программист")
elif x % 10 >= 2 and x % 10 <= 4:
    print(x, "программиста")
else:
    print(x, "программистов")
# Out:
# 500
# 500 програмистов

# %%
495 % 10
# Out:
# 5

# %%
for x in range(1001):

    if x >= 11 and x <= 19:
        print(x, "программистов")
    elif x % 100 >= 11 and x % 100 <= 14:
        print(x, "программистов")
    elif x % 10 == 1:
        print(x, "программист")
    elif x % 10 >= 2 and x % 10 <= 4:
        print(x, "программиста")
    else:
        print(x, "программистов")
# Out:
# 0 программистов
# 1 программист
# 2 программиста
# 3 программиста
# 4 программиста
# 5 программистов
# 6 программистов
# 7 программистов
# 8 программистов
# 9 программистов
# 10 программистов
# 11 программистов
# 12 программистов
# 13 программистов
# 14 программистов
# 15 программистов
# 16 программистов
# 17 программистов
# 18 программистов
# 19 программистов
# 20 программистов
# 21 программист
# 22 программиста
# 23 программиста
# 24 программиста
# 25 программистов
# 26 программистов
# 27 программистов
# 28 программистов
# 29 программистов
# 30 программистов
# 31 программист
# 32 программиста
# 33 программиста
# 34 программиста
# 35 программистов
# 36 программистов
# 37 программистов
# 38 программистов
# 39 программистов
# 40 программистов
# 41 программист
# 42 программиста
# 43 программиста
# 44 программиста
# 45 программистов
# 46 программистов
# 47 программистов
# 48 программистов
# 49 программистов
# 50 программистов
# 51 программист
# 52 программиста
# 53 программиста
# 54 программиста
# 55 программистов
# 56 программистов
# 57 программистов
# 58 программистов
# 59 программистов
# 60 программистов
# 61 программист
# 62 программиста
# 63 программиста
# 64 программиста
# 65 программистов
# 66 программистов
# 67 программистов
# 68 программистов
# 69 программистов
# 70 программистов
# 71 программист
# 72 программиста
# 73 программиста
# 74 программиста
# 75 программистов
# 76 программистов
# 77 программистов
# 78 программистов
# 79 программистов
# 80 программистов
# 81 программист
# 82 программиста
# 83 программиста
# 84 программиста
# 85 программистов
# 86 программистов
# 87 программистов
# 88 программистов
# 89 программистов
# 90 программистов
# 91 программист
# 92 программиста
# 93 программиста
# 94 программиста
# 95 программистов
# 96 программистов
# 97 программистов
# 98 программистов
# 99 программистов
# 100 программистов
# 101 программист
# 102 программиста
# 103 программиста
# 104 программиста
# 105 программистов
# 106 программистов
# 107 программистов
# 108 программистов
# 109 программистов
# 110 программистов
# 111 программистов
# 112 программистов
# 113 программистов
# 114 программистов
# 115 программистов
# 116 программистов
# 117 программистов
# 118 программистов
# 119 программистов
# 120 программистов
# 121 программист
# 122 программиста
# 123 программиста
# 124 программиста
# 125 программистов
# 126 программистов
# 127 программистов
# 128 программистов
# 129 программистов
# 130 программистов
# 131 программист
# 132 программиста
# 133 программиста
# 134 программиста
# 135 программистов
# 136 программистов
# 137 программистов
# 138 программистов
# 139 программистов
# 140 программистов
# 141 программист
# 142 программиста
# 143 программиста
# 144 программиста
# 145 программистов
# 146 программистов
# 147 программистов
# 148 программистов
# 149 программистов
# 150 программистов
# 151 программист
# 152 программиста
# 153 программиста
# 154 программиста
# 155 программистов
# 156 программистов
# 157 программистов
# 158 программистов
# 159 программистов
# 160 программистов
# 161 программист
# 162 программиста
# 163 программиста
# 164 программиста
# 165 программистов
# 166 программистов
# 167 программистов
# 168 программистов
# 169 программистов
# 170 программистов
# 171 программист
# 172 программиста
# 173 программиста
# 174 программиста
# 175 программистов
# 176 программистов
# 177 программистов
# 178 программистов
# 179 программистов
# 180 программистов
# 181 программист
# 182 программиста
# 183 программиста
# 184 программиста
# 185 программистов
# 186 программистов
# 187 программистов
# 188 программистов
# 189 программистов
# 190 программистов
# 191 программист
# 192 программиста
# 193 программиста
# 194 программиста
# 195 программистов
# 196 программистов
# 197 программистов
# 198 программистов
# 199 программистов
# 200 программистов
# 201 программист
# 202 программиста
# 203 программиста
# 204 программиста
# 205 программистов
# 206 программистов
# 207 программистов
# 208 программистов
# 209 программистов
# 210 программистов
# 211 программистов
# 212 программистов
# 213 программистов
# 214 программистов
# 215 программистов
# 216 программистов
# 217 программистов
# 218 программистов
# 219 программистов
# 220 программистов
# 221 программист
# 222 программиста
# 223 программиста
# 224 программиста
# 225 программистов
# 226 программистов
# 227 программистов
# 228 программистов
# 229 программистов
# 230 программистов
# 231 программист
# 232 программиста
# 233 программиста
# 234 программиста
# 235 программистов
# 236 программистов
# 237 программистов
# 238 программистов
# 239 программистов
# 240 программистов
# 241 программист
# 242 программиста
# 243 программиста
# 244 программиста
# 245 программистов
# 246 программистов
# 247 программистов
# 248 программистов
# 249 программистов
# 250 программистов
# 251 программист
# 252 программиста
# 253 программиста
# 254 программиста
# 255 программистов
# 256 программистов
# 257 программистов
# 258 программистов
# 259 программистов
# 260 программистов
# 261 программист
# 262 программиста
# 263 программиста
# 264 программиста
# 265 программистов
# 266 программистов
# 267 программистов
# 268 программистов
# 269 программистов
# 270 программистов
# 271 программист
# 272 программиста
# 273 программиста
# 274 программиста
# 275 программистов
# 276 программистов
# 277 программистов
# 278 программистов
# 279 программистов
# 280 программистов
# 281 программист
# 282 программиста
# 283 программиста
# 284 программиста
# 285 программистов
# 286 программистов
# 287 программистов
# 288 программистов
# 289 программистов
# 290 программистов
# 291 программист
# 292 программиста
# 293 программиста
# 294 программиста
# 295 программистов
# 296 программистов
# 297 программистов
# 298 программистов
# 299 программистов
# 300 программистов
# 301 программист
# 302 программиста
# 303 программиста
# 304 программиста
# 305 программистов
# 306 программистов
# 307 программистов
# 308 программистов
# 309 программистов
# 310 программистов
# 311 программистов
# 312 программистов
# 313 программистов
# 314 программистов
# 315 программистов
# 316 программистов
# 317 программистов
# 318 программистов
# 319 программистов
# 320 программистов
# 321 программист
# 322 программиста
# 323 программиста
# 324 программиста
# 325 программистов
# 326 программистов
# 327 программистов
# 328 программистов
# 329 программистов
# 330 программистов
# 331 программист
# 332 программиста
# 333 программиста
# 334 программиста
# 335 программистов
# 336 программистов
# 337 программистов
# 338 программистов
# 339 программистов
# 340 программистов
# 341 программист
# 342 программиста
# 343 программиста
# 344 программиста
# 345 программистов
# 346 программистов
# 347 программистов
# 348 программистов
# 349 программистов
# 350 программистов
# 351 программист
# 352 программиста
# 353 программиста
# 354 программиста
# 355 программистов
# 356 программистов
# 357 программистов
# 358 программистов
# 359 программистов
# 360 программистов
# 361 программист
# 362 программиста
# 363 программиста
# 364 программиста
# 365 программистов
# 366 программистов
# 367 программистов
# 368 программистов
# 369 программистов
# 370 программистов
# 371 программист
# 372 программиста
# 373 программиста
# 374 программиста
# 375 программистов
# 376 программистов
# 377 программистов
# 378 программистов
# 379 программистов
# 380 программистов
# 381 программист
# 382 программиста
# 383 программиста
# 384 программиста
# 385 программистов
# 386 программистов
# 387 программистов
# 388 программистов
# 389 программистов
# 390 программистов
# 391 программист
# 392 программиста
# 393 программиста
# 394 программиста
# 395 программистов
# 396 программистов
# 397 программистов
# 398 программистов
# 399 программистов
# 400 программистов
# 401 программист
# 402 программиста
# 403 программиста
# 404 программиста
# 405 программистов
# 406 программистов
# 407 программистов
# 408 программистов
# 409 программистов
# 410 программистов
# 411 программистов
# 412 программистов
# 413 программистов
# 414 программистов
# 415 программистов
# 416 программистов
# 417 программистов
# 418 программистов
# 419 программистов
# 420 программистов
# 421 программист
# 422 программиста
# 423 программиста
# 424 программиста
# 425 программистов
# 426 программистов
# 427 программистов
# 428 программистов
# 429 программистов
# 430 программистов
# 431 программист
# 432 программиста
# 433 программиста
# 434 программиста
# 435 программистов
# 436 программистов
# 437 программистов
# 438 программистов
# 439 программистов
# 440 программистов
# 441 программист
# 442 программиста
# 443 программиста
# 444 программиста
# 445 программистов
# 446 программистов
# 447 программистов
# 448 программистов
# 449 программистов
# 450 программистов
# 451 программист
# 452 программиста
# 453 программиста
# 454 программиста
# 455 программистов
# 456 программистов
# 457 программистов
# 458 программистов
# 459 программистов
# 460 программистов
# 461 программист
# 462 программиста
# 463 программиста
# 464 программиста
# 465 программистов
# 466 программистов
# 467 программистов
# 468 программистов
# 469 программистов
# 470 программистов
# 471 программист
# 472 программиста
# 473 программиста
# 474 программиста
# 475 программистов
# 476 программистов
# 477 программистов
# 478 программистов
# 479 программистов
# 480 программистов
# 481 программист
# 482 программиста
# 483 программиста
# 484 программиста
# 485 программистов
# 486 программистов
# 487 программистов
# 488 программистов
# 489 программистов
# 490 программистов
# 491 программист
# 492 программиста
# 493 программиста
# 494 программиста
# 495 программистов
# 496 программистов
# 497 программистов
# 498 программистов
# 499 программистов
# 500 программистов
# 501 программист
# 502 программиста
# 503 программиста
# 504 программиста
# 505 программистов
# 506 программистов
# 507 программистов
# 508 программистов
# 509 программистов
# 510 программистов
# 511 программистов
# 512 программистов
# 513 программистов
# 514 программистов
# 515 программистов
# 516 программистов
# 517 программистов
# 518 программистов
# 519 программистов
# 520 программистов
# 521 программист
# 522 программиста
# 523 программиста
# 524 программиста
# 525 программистов
# 526 программистов
# 527 программистов
# 528 программистов
# 529 программистов
# 530 программистов
# 531 программист
# 532 программиста
# 533 программиста
# 534 программиста
# 535 программистов
# 536 программистов
# 537 программистов
# 538 программистов
# 539 программистов
# 540 программистов
# 541 программист
# 542 программиста
# 543 программиста
# 544 программиста
# 545 программистов
# 546 программистов
# 547 программистов
# 548 программистов
# 549 программистов
# 550 программистов
# 551 программист
# 552 программиста
# 553 программиста
# 554 программиста
# 555 программистов
# 556 программистов
# 557 программистов
# 558 программистов
# 559 программистов
# 560 программистов
# 561 программист
# 562 программиста
# 563 программиста
# 564 программиста
# 565 программистов
# 566 программистов
# 567 программистов
# 568 программистов
# 569 программистов
# 570 программистов
# 571 программист
# 572 программиста
# 573 программиста
# 574 программиста
# 575 программистов
# 576 программистов
# 577 программистов
# 578 программистов
# 579 программистов
# 580 программистов
# 581 программист
# 582 программиста
# 583 программиста
# 584 программиста
# 585 программистов
# 586 программистов
# 587 программистов
# 588 программистов
# 589 программистов
# 590 программистов
# 591 программист
# 592 программиста
# 593 программиста
# 594 программиста
# 595 программистов
# 596 программистов
# 597 программистов
# 598 программистов
# 599 программистов
# 600 программистов
# 601 программист
# 602 программиста
# 603 программиста
# 604 программиста
# 605 программистов
# 606 программистов
# 607 программистов
# 608 программистов
# 609 программистов
# 610 программистов
# 611 программистов
# 612 программистов
# 613 программистов
# 614 программистов
# 615 программистов
# 616 программистов
# 617 программистов
# 618 программистов
# 619 программистов
# 620 программистов
# 621 программист
# 622 программиста
# 623 программиста
# 624 программиста
# 625 программистов
# 626 программистов
# 627 программистов
# 628 программистов
# 629 программистов
# 630 программистов
# 631 программист
# 632 программиста
# 633 программиста
# 634 программиста
# 635 программистов
# 636 программистов
# 637 программистов
# 638 программистов
# 639 программистов
# 640 программистов
# 641 программист
# 642 программиста
# 643 программиста
# 644 программиста
# 645 программистов
# 646 программистов
# 647 программистов
# 648 программистов
# 649 программистов
# 650 программистов
# 651 программист
# 652 программиста
# 653 программиста
# 654 программиста
# 655 программистов
# 656 программистов
# 657 программистов
# 658 программистов
# 659 программистов
# 660 программистов
# 661 программист
# 662 программиста
# 663 программиста
# 664 программиста
# 665 программистов
# 666 программистов
# 667 программистов
# 668 программистов
# 669 программистов
# 670 программистов
# 671 программист
# 672 программиста
# 673 программиста
# 674 программиста
# 675 программистов
# 676 программистов
# 677 программистов
# 678 программистов
# 679 программистов
# 680 программистов
# 681 программист
# 682 программиста
# 683 программиста
# 684 программиста
# 685 программистов
# 686 программистов
# 687 программистов
# 688 программистов
# 689 программистов
# 690 программистов
# 691 программист
# 692 программиста
# 693 программиста
# 694 программиста
# 695 программистов
# 696 программистов
# 697 программистов
# 698 программистов
# 699 программистов
# 700 программистов
# 701 программист
# 702 программиста
# 703 программиста
# 704 программиста
# 705 программистов
# 706 программистов
# 707 программистов
# 708 программистов
# 709 программистов
# 710 программистов
# 711 программистов
# 712 программистов
# 713 программистов
# 714 программистов
# 715 программистов
# 716 программистов
# 717 программистов
# 718 программистов
# 719 программистов
# 720 программистов
# 721 программист
# 722 программиста
# 723 программиста
# 724 программиста
# 725 программистов
# 726 программистов
# 727 программистов
# 728 программистов
# 729 программистов
# 730 программистов
# 731 программист
# 732 программиста
# 733 программиста
# 734 программиста
# 735 программистов
# 736 программистов
# 737 программистов
# 738 программистов
# 739 программистов
# 740 программистов
# 741 программист
# 742 программиста
# 743 программиста
# 744 программиста
# 745 программистов
# 746 программистов
# 747 программистов
# 748 программистов
# 749 программистов
# 750 программистов
# 751 программист
# 752 программиста
# 753 программиста
# 754 программиста
# 755 программистов
# 756 программистов
# 757 программистов
# 758 программистов
# 759 программистов
# 760 программистов
# 761 программист
# 762 программиста
# 763 программиста
# 764 программиста
# 765 программистов
# 766 программистов
# 767 программистов
# 768 программистов
# 769 программистов
# 770 программистов
# 771 программист
# 772 программиста
# 773 программиста
# 774 программиста
# 775 программистов
# 776 программистов
# 777 программистов
# 778 программистов
# 779 программистов
# 780 программистов
# 781 программист
# 782 программиста
# 783 программиста
# 784 программиста
# 785 программистов
# 786 программистов
# 787 программистов
# 788 программистов
# 789 программистов
# 790 программистов
# 791 программист
# 792 программиста
# 793 программиста
# 794 программиста
# 795 программистов
# 796 программистов
# 797 программистов
# 798 программистов
# 799 программистов
# 800 программистов
# 801 программист
# 802 программиста
# 803 программиста
# 804 программиста
# 805 программистов
# 806 программистов
# 807 программистов
# 808 программистов
# 809 программистов
# 810 программистов
# 811 программистов
# 812 программистов
# 813 программистов
# 814 программистов
# 815 программистов
# 816 программистов
# 817 программистов
# 818 программистов
# 819 программистов
# 820 программистов
# 821 программист
# 822 программиста
# 823 программиста
# 824 программиста
# 825 программистов
# 826 программистов
# 827 программистов
# 828 программистов
# 829 программистов
# 830 программистов
# 831 программист
# 832 программиста
# 833 программиста
# 834 программиста
# 835 программистов
# 836 программистов
# 837 программистов
# 838 программистов
# 839 программистов
# 840 программистов
# 841 программист
# 842 программиста
# 843 программиста
# 844 программиста
# 845 программистов
# 846 программистов
# 847 программистов
# 848 программистов
# 849 программистов
# 850 программистов
# 851 программист
# 852 программиста
# 853 программиста
# 854 программиста
# 855 программистов
# 856 программистов
# 857 программистов
# 858 программистов
# 859 программистов
# 860 программистов
# 861 программист
# 862 программиста
# 863 программиста
# 864 программиста
# 865 программистов
# 866 программистов
# 867 программистов
# 868 программистов
# 869 программистов
# 870 программистов
# 871 программист
# 872 программиста
# 873 программиста
# 874 программиста
# 875 программистов
# 876 программистов
# 877 программистов
# 878 программистов
# 879 программистов
# 880 программистов
# 881 программист
# 882 программиста
# 883 программиста
# 884 программиста
# 885 программистов
# 886 программистов
# 887 программистов
# 888 программистов
# 889 программистов
# 890 программистов
# 891 программист
# 892 программиста
# 893 программиста
# 894 программиста
# 895 программистов
# 896 программистов
# 897 программистов
# 898 программистов
# 899 программистов
# 900 программистов
# 901 программист
# 902 программиста
# 903 программиста
# 904 программиста
# 905 программистов
# 906 программистов
# 907 программистов
# 908 программистов
# 909 программистов
# 910 программистов
# 911 программистов
# 912 программистов
# 913 программистов
# 914 программистов
# 915 программистов
# 916 программистов
# 917 программистов
# 918 программистов
# 919 программистов
# 920 программистов
# 921 программист
# 922 программиста
# 923 программиста
# 924 программиста
# 925 программистов
# 926 программистов
# 927 программистов
# 928 программистов
# 929 программистов
# 930 программистов
# 931 программист
# 932 программиста
# 933 программиста
# 934 программиста
# 935 программистов
# 936 программистов
# 937 программистов
# 938 программистов
# 939 программистов
# 940 программистов
# 941 программист
# 942 программиста
# 943 программиста
# 944 программиста
# 945 программистов
# 946 программистов
# 947 программистов
# 948 программистов
# 949 программистов
# 950 программистов
# 951 программист
# 952 программиста
# 953 программиста
# 954 программиста
# 955 программистов
# 956 программистов
# 957 программистов
# 958 программистов
# 959 программистов
# 960 программистов
# 961 программист
# 962 программиста
# 963 программиста
# 964 программиста
# 965 программистов
# 966 программистов
# 967 программистов
# 968 программистов
# 969 программистов
# 970 программистов
# 971 программист
# 972 программиста
# 973 программиста
# 974 программиста
# 975 программистов
# 976 программистов
# 977 программистов
# 978 программистов
# 979 программистов
# 980 программистов
# 981 программист
# 982 программиста
# 983 программиста
# 984 программиста
# 985 программистов
# 986 программистов
# 987 программистов
# 988 программистов
# 989 программистов
# 990 программистов
# 991 программист
# 992 программиста
# 993 программиста
# 994 программиста
# 995 программистов
# 996 программистов
# 997 программистов
# 998 программистов
# 999 программистов
# 1000 программистов

# %%
value = int(input())
v1 = int(value // 100000)
v2 = int(value // 10000 % 10)
v3 = int(value // 1000  % 10)
v4 = int(value % 1000 // 100)
v5 = int(value % 100 // 10)
v6 = int(value % 10)
if v1 + v2 + v3 == v4 + v5 + v6:
    print("Счастливый")
else:
    print("Обычный")
# Out:
# 123574
# Обычный

# %%
a, b = int(input()), int(input())
d = 1
while True:
    if d % a == 0 and d % b == 0:
        break
    d += 1
print(d)
# Out:
# 1722

# %%
a, b = int(input()), int(input())
d = a
while d%b:
    d += a
    print(d)
print(d)
# Out:
# 106
# 159
# 212
# 265
# 318
# 371
# 424
# 477
# 530
# 583
# 636
# 689
# 742
# 795
# 848
# 901
# 954
# 1007
# 1060
# 1113
# 1166
# 1219
# 1272
# 1325
# 1378
# 1431
# 1484
# 1537
# 1590
# 1643
# 1696
# 1749
# 1802
# 1855
# 1908
# 1961
# 2014
# 2067
# 2120
# 2173
# 2226
# 2279
# 2332
# 2385
# 2438
# 2491
# 2544
# 2597
# 2650
# 2703
# 2756
# 2809
# 2862
# 2915
# 2968
# 3021
# 3074
# 3127
# 3180
# 3233
# 3286
# 3339
# 3392
# 3445
# 3498
# 3551
# 3604
# 3657
# 3710
# 3763
# 3816
# 3869
# 3922
# 3975
# 4028
# 4081
# 4134
# 4187
# 4240
# 4293
# 4346
# 4399
# 4452
# 4505
# 4558
# 4611
# 4664
# 4717
# 4770
# 4823
# 4876
# 4929
# 4982
# 5035
# 5088
# 5141
# 5194
# 5247
# 5300
# 5353
# 5406
# 5459
# 5512
# 5565
# 5618
# 5671
# 5724
# 5777
# 5830
# 5883
# 5936
# 5989
# 6042
# 6095
# 6148
# 6201
# 6254
# 6307
# 6360
# 6413
# 6466
# 6519
# 6572
# 6625
# 6678
# 6731
# 6784
# 6837
# 6890
# 6943
# 6996
# 7049
# 7102
# 7155
# 7208
# 7261
# 7314
# 7367
# 7420
# 7473
# 7526
# 7579
# 7632
# 7685
# 7738
# 7791
# 7844
# 7897
# 7950
# 8003
# 8056
# 8109
# 8162
# 8215
# 8268
# 8321
# 8374
# 8427
# 8480
# 8533
# 8586
# 8639
# 8692
# 8745
# 8798
# 8851
# 8904
# 8957
# 9010
# 9063
# 9116
# 9169
# 9222
# 9275
# 9328
# 9381
# 9434
# 9487
# 9540
# 9593
# 9646
# 9699
# 9752
# 9805
# 9858
# 9911
# 9964
# 10017
# 10070
# 10123
# 10176
# 10229
# 10282
# 10335
# 10388
# 10441
# 10494
# 10547
# 10600
# 10653
# 10706
# 10759
# 10812
# 10865
# 10918
# 10971
# 11024
# 11077
# 11130
# 11183
# 11236
# 11289
# 11342
# 11395
# 11448
# 11501
# 11554
# 11607
# 11660
# 11713
# 11766
# 11819
# 11872
# 11925
# 11978
# 12031
# 12084
# 12137
# 12190
# 12243
# 12296
# 12349
# 12402
# 12455
# 12508
# 12561
# 12614
# 12667
# 12720
# 12773
# 12826
# 12879
# 12932
# 12985
# 13038
# 13091
# 13144
# 13197
# 13250
# 13303
# 13356
# 13409
# 13462
# 13515
# 13568
# 13621
# 13674
# 13727
# 13780
# 13833
# 13886
# 13939
# 13992
# 14045
# 14098
# 14151
# 14204
# 14257
# 14310
# 14363
# 14416
# 14469
# 14522
# 14575
# 14628
# 14681
# 14734
# 14787
# 14840
# 14893
# 14946
# 14999
# 15052
# 15105
# 15158
# 15211
# 15264
# 15317
# 15370
# 15423
# 15476
# 15529
# 15582
# 15635
# 15688
# 15741
# 15794
# 15847
# 15900
# 15953
# 16006
# 16059
# 16112
# 16165
# 16218
# 16271
# 16324
# 16377
# 16430
# 16483
# 16536
# 16589
# 16642
# 16695
# 16748
# 16801
# 16854
# 16907
# 16960
# 17013
# 17066
# 17119
# 17172
# 17225
# 17278
# 17331
# 17384
# 17437
# 17490
# 17543
# 17596
# 17649
# 17702
# 17755
# 17808
# 17861
# 17914
# 17967
# 18020
# 18073
# 18126
# 18179
# 18232
# 18285
# 18338
# 18391
# 18444
# 18497
# 18550
# 18603
# 18656
# 18709
# 18762
# 18815
# 18868
# 18921
# 18974
# 19027
# 19080
# 19133
# 19186
# 19239
# 19292
# 19345
# 19398
# 19451
# 19504
# 19557
# 19610
# 19663
# 19716
# 19769
# 19822
# 19875
# 19928
# 19981
# 20034
# 20087
# 20140
# 20193
# 20246
# 20299
# 20352
# 20405
# 20458
# 20511
# 20564
# 20617
# 20670
# 20723
# 20776
# 20829
# 20882
# 20935
# 20988
# 21041
# 21094
# 21147
# 21200
# 21253
# 21306
# 21359
# 21412
# 21465
# 21518
# 21571
# 21624
# 21677
# 21730
# 21783
# 21836
# 21889
# 21942
# 21995
# 22048
# 22101
# 22154
# 22207
# 22260
# 22313
# 22366
# 22419
# 22472
# 22525
# 22578
# 22631
# 22684
# 22737
# 22790
# 22843
# 22896
# 22949
# 23002
# 23055
# 23108
# 23161
# 23214
# 23267
# 23320
# 23373
# 23426
# 23479
# 23532
# 23585
# 23638
# 23691
# 23744
# 23797
# 23850
# 23903
# 23956
# 24009
# 24062
# 24115
# 24168
# 24221
# 24274
# 24327
# 24380
# 24433
# 24486
# 24539
# 24592
# 24645
# 24698
# 24751
# 24804
# 24857
# 24910
# 24963
# 25016
# 25069
# 25122
# 25175
# 25228
# 25281
# 25334
# 25387
# 25440
# 25493
# 25546
# 25599
# 25652
# 25705
# 25758
# 25811
# 25864
# 25917
# 25970
# 26023
# 26076
# 26129
# 26182
# 26235
# 26288
# 26341
# 26394
# 26447
# 26500
# 26553
# 26606
# 26659
# 26712
# 26765
# 26818
# 26871
# 26924
# 26977
# 27030
# 27083
# 27136
# 27189
# 27242
# 27295
# 27348
# 27401
# 27454
# 27507
# 27560
# 27613
# 27666
# 27719
# 27772
# 27825
# 27878
# 27931
# 27984
# 28037
# 28090
# 28143
# 28196
# 28196

# %%
i = 0
while i < 5:
    a, b = input().split()
    a = int(a)
    b = int(b)
    if (a == 0) and (b == 0):
        break
    print(a*b)
    i += 1
# Out:
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-46034a3acdf3> in <module>
#       1 i = 0
#       2 while i < 5:
# ----> 3     a, b = input().split()
#       4     a = int(a)
#       5     b = int(b)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
i = 0
while i < 5:
    a, b = input().split()
    a = int(a)
    b = int(b)
    if (a == 0) and (b == 0):
        break
    if (a == 0) or (b == 0):
        continue
    print(a*b)
    i += 1
# Out:
# 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-aa3076bf97cd> in <module>
#       1 i = 0
#       2 while i < 5:
# ----> 3     a, b = input().split()
#       4     a = int(a)
#       5     b = int(b)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
i = 0
s = 0
while i < 10:
    i = i + 1
    s = s + i
    if s > 15:
        break
    i = i + 1
    print(i)
    print(s)
# Out:
# 2
# 1
# 4
# 4
# 6
# 9

# %%
i = 0
s = 0
while i < 10:
    i = i + 1
    s = s + i
    if s > 15:
        continue
    i = i + 1
